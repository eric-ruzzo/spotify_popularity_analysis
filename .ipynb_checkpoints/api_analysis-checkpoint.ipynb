# %%
# Import dependencies

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from config import client_id, secret, api_key

# %%
# Establish connection to Spotify

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Create empty lists to store data from API calls

artist_name = []
track_name = []
track_id = []
popularity = []
artist_id = []

# Run a for loop to call the API multiple times for a list of tracks

# i represents each call of the Spotify search API, range is maximum results, step 50 represents 50 results per search
for i in range(0,2000,50):
    
    # Save results of each search as a variable. Limit search to 50 results, use offset to skip previous result of iteration
    track_results = sp.search(q='year:2019', type='track', limit=50,offset=i)
    
    # Loop through each result to find values for selected fields
    # Enumerate creates a tuple of each track result for iteration. Example: (0, J. Cole), (1, Ariana Grande), etc.
    for i, t in enumerate(track_results['tracks']['items']):
        artist_id.append(t['artists'][0]['id'])
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
genres = []

for artist in range(0,2000):
    artist_results = sp.artist(artist_id[artist])
    genres.append(artist_results["genres"])

# %%
# Create empty lists to store audio feature values
danceability = []
energy = []
loudness = []
valence = []
tempo = []

for track in range(0,2000):
    try:
        audio_features = sp.audio_features(track_id[track])
        danceability.append(audio_features[0]["danceability"])
        energy.append(audio_features[0]["energy"])
        loudness.append(audio_features[0]["loudness"])
        valence.append(audio_features[0]["valence"])
        tempo.append(audio_features[0]["tempo"])
    except TypeError:
        danceability.append(0)
        energy.append(0)
        loudness.append(0)
        valence.append(0)
        tempo.append(0)

# %%
features_df = pd.DataFrame({"Track ID": track_id, "Artist Name": artist_name, "Track Name":track_name,
                            "Danceability":danceability, "Energy":energy, "Loudness":loudness,
                            "Valence":valence, "Tempo": tempo, "Popularity": popularity})
features_df = features_df.loc[features_df["Energy"] != 0]
features_df.to_csv("audio_features.csv", index=False)
features_df.head()
# Out:
#                  Track ID     Artist Name  \
# 0  2JvzF1RMd7lE3KmFlsyZD8         J. Cole
# 1  53CJANUxooaqGOtdsBTh7O       Lil Nas X
# 2  2Fxmhks0bxGSBdJ92vM42m   Billie Eilish
# 3  4kV4N9D1iKVxx1KLvtTpjS   Ariana Grande
# 4  4y3OI86AEP6PQoDE6olYhO  Jonas Brothers
#
#                                  Track Name  Danceability  Energy  Loudness  \
# 0                              MIDDLE CHILD         0.837   0.364   -11.713
# 1                             Old Town Road         0.908   0.517    -6.063
# 2                                   bad guy         0.708   0.418   -10.998
# 3  break up with your girlfriend, i'm bored         0.726   0.554    -5.290
# 4                                    Sucker         0.842   0.734    -5.065
#
#    Valence    Tempo  Popularity
# 0    0.463  123.984          96
# 1    0.471  136.019          95
# 2    0.578  131.926          98
# 3    0.335  169.999          98
# 4    0.952  137.958          98

# %%
genre_df = pd.DataFrame({"Artist ID": artist_id, "Artist Name": artist_name, "Genres": genres})
genre_df.to_csv("genres.csv", index=False)
genre_df.head()
# Out:
#                 Artist ID     Artist Name  \
# 0  6l3HvQ5sa6mXTsMTB19rO5         J. Cole
# 1  7jVv8c5Fj3E9VhNjxT4snq       Lil Nas X
# 2  6qqNVTkY8uBg9cP3Jd7DAH   Billie Eilish
# 3  66CXWjxzNUsdJxJ2JdwvnR   Ariana Grande
# 4  7gOdHgIoIKoe4i9Tta6qdD  Jonas Brothers
#
#                                           Genres
# 0  [conscious hip hop, nc hip hop, pop rap, rap]
# 1                                             []
# 2                                   [electropop]
# 3                [dance pop, pop, post-teen pop]
# 4      [boy band, dance pop, pop, post-teen pop]

# %%
popularity_df = pd.DataFrame({"Artist ID": artist_id, "Artist Name": artist_name, "Track ID": track_id,
                              "Track Name": track_name, "Popularity Score": popularity})
popularity_df.to_csv("popularity.csv", index=False)
popularity_df.head()
# Out:
#                 Artist ID     Artist Name                Track ID  \
# 0  6l3HvQ5sa6mXTsMTB19rO5         J. Cole  2JvzF1RMd7lE3KmFlsyZD8
# 1  7jVv8c5Fj3E9VhNjxT4snq       Lil Nas X  53CJANUxooaqGOtdsBTh7O
# 2  6qqNVTkY8uBg9cP3Jd7DAH   Billie Eilish  2Fxmhks0bxGSBdJ92vM42m
# 3  66CXWjxzNUsdJxJ2JdwvnR   Ariana Grande  4kV4N9D1iKVxx1KLvtTpjS
# 4  7gOdHgIoIKoe4i9Tta6qdD  Jonas Brothers  4y3OI86AEP6PQoDE6olYhO
#
#                                  Track Name  Popularity Score
# 0                              MIDDLE CHILD                96
# 1                             Old Town Road                95
# 2                                   bad guy                98
# 3  break up with your girlfriend, i'm bored                98
# 4                                    Sucker                98

# %%
popularity_df["Popularity Score"].max()
# Out:
# 100

# %%
split_genres = []
split_artists = []
split_track = []
split_popularity = []
category = []

for x in range(len(genres)):
    #print(genres[x])
    for y in genres[x]:
        #print(y, artist_name[x])
        split_genres.append(y)
        split_artists.append(artist_name[x])
        split_track.append(track_name[x])
        split_popularity.append(popularity[x])

# %%
split_df = pd.DataFrame({"Artist Name": split_artists, "Track Name": split_track,
                         "Genre": split_genres, "Popularity Score": split_popularity})
split_df = split_df.loc[split_df["Popularity Score"] >= 1]
split_df.to_csv("split_genre.csv", index=False)
split_df.head()
# Out:
#      Artist Name    Track Name              Genre  Popularity Score
# 0        J. Cole  MIDDLE CHILD  conscious hip hop                96
# 1        J. Cole  MIDDLE CHILD         nc hip hop                96
# 2        J. Cole  MIDDLE CHILD            pop rap                96
# 3        J. Cole  MIDDLE CHILD                rap                96
# 4  Billie Eilish       bad guy         electropop                98

# %%
avg_pop_df = split_df.groupby("Genre").mean()
count_pop_df = split_df.groupby("Genre").count()
count_pop_df = count_pop_df.drop(columns=["Artist Name", "Track Name"])
count_pop_df = count_pop_df.sort_values(by=["Popularity Score"], ascending=False).nlargest(20, "Popularity Score")
count_pop_df.head(20)
# Out:
#                       Popularity Score
# Genre
# pop                                554
# rap                                309
# trap music                         271
# pop rap                            264
# dance pop                          249
# hip hop                            167
# southern hip hop                   164
# post-teen pop                      152
# electropop                         114
# contemporary country               113
# edm                                109
# modern rock                        101
# r&b                                101
# atl hip hop                         93
# tropical house                      91
# country road                        88
# vapor trap                          78
# underground hip hop                 72
# country                             72
# latin                               67

# %%
genre_popularity_df = pd.merge(count_pop_df, avg_pop_df, on="Genre", how="left")
genre_popularity_df = genre_popularity_df.rename(columns={"Popularity Score_x": "Genre Count",
                                                       "Popularity Score_y": "Average Popularity Score"})
genre_popularity_df = genre_popularity_df.sort_values(by="Average Popularity Score")
genre_popularity_df.head(20)
# Out:
#                       Genre Count  Average Popularity Score
# Genre
# country                        72                 61.097222
# contemporary country          113                 61.778761
# country road                   88                 62.000000
# underground hip hop            72                 62.125000
# r&b                           101                 63.851485
# modern rock                   101                 63.940594
# vapor trap                     78                 64.794872
# hip hop                       167                 65.341317
# edm                           109                 65.724771
# pop rap                       264                 65.787879
# southern hip hop              164                 65.890244
# dance pop                     249                 66.421687
# rap                           309                 66.699029
# latin                          67                 67.164179
# tropical house                 91                 67.208791
# trap music                    271                 67.564576
# pop                           554                 67.790614
# post-teen pop                 152                 68.842105
# electropop                    114                 70.043860
# atl hip hop                    93                 70.322581

# %%
y = np.arange(0, len(genre_popularity_df))
ticks = genre_popularity_df.index
width = genre_popularity_df["Average Popularity Score"]

genre_plot = plt.barh(y, width, color="#1DB954")
plt.yticks(ticks=y, labels=ticks)
plt.xticks(ticks=np.arange(0, genre_popularity_df["Average Popularity Score"].max(), 5))
plt.tick_params(axis="y")
plt.ylim(-0.8, 19.8)
plt.xlim(0, 71)
plt.rcParams["figure.figsize"] = (20,12)
plt.title("Top 20 Most Popular Genres on Spotify")
plt.xlabel("Average Popularity Score")
plt.ylabel("Genre")
plt.grid(axis="x")
plt.rcParams.update({'font.size': 16})
plt.show()

# ISSUE: Too many ticks

# %%
features_df["Energy"].min()
# Out:
# 0.00166

# %%
fig, ((ax1, ax2, ax3),(ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
fig.delaxes(ax6)

dance_x = features_df["Danceability"]
energy_x = features_df["Energy"]
loudness_x = features_df["Loudness"]
valence_x = features_df["Valence"]
tempo_x = features_df["Tempo"]
y = features_df["Popularity"]

ax1.scatter(dance_x, y)
ax2.scatter(energy_x, y)
ax3.scatter(loudness_x, y)
ax4.scatter(valence_x, y)
ax5.scatter(tempo_x, y)
plt.rcParams["figure.figsize"] = (20,12)
plt.show()

# %%
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
fig.delaxes(ax2)

dance_x = features_df["Danceability"]
energy_x = features_df["Energy"]
loudness_x = features_df["Loudness"]
valence_x = features_df["Valence"]
tempo_x = features_df["Tempo"]
y = features_df["Popularity"]

ax1.scatter(dance_x, y)
ax1.scatter(energy_x, y)
ax1.scatter(valence_x, y)
ax3.scatter(loudness_x, y)
ax4.scatter(tempo_x, y)
plt.rcParams["figure.figsize"] = (20,12)
plt.show()
